# %% [markdown]
# <a href="https://colab.research.google.com/github/princy620/Projects/blob/main/Opencv_Session_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Step-1: Install the required packages
#
# package name: opencv-python

# %%
# !pip install opencv-python

# %% [markdown]
# Step-2: Import the packages

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
dir(cv2)
# Out:
# ['ACCESS_FAST',
#  'ACCESS_MASK',
#  'ACCESS_READ',
#  'ACCESS_RW',
#  'ACCESS_WRITE',
#  'ADAPTIVE_THRESH_GAUSSIAN_C',
#  'ADAPTIVE_THRESH_MEAN_C',
#  'AGAST_FEATURE_DETECTOR_AGAST_5_8',
#  'AGAST_FEATURE_DETECTOR_AGAST_7_12D',
#  'AGAST_FEATURE_DETECTOR_AGAST_7_12S',
#  'AGAST_FEATURE_DETECTOR_NONMAX_SUPPRESSION',
#  'AGAST_FEATURE_DETECTOR_OAST_9_16',
#  'AGAST_FEATURE_DETECTOR_THRESHOLD',
#  'AKAZE',
#  'AKAZE_DESCRIPTOR_KAZE',
#  'AKAZE_DESCRIPTOR_KAZE_UPRIGHT',
#  'AKAZE_DESCRIPTOR_MLDB',
#  'AKAZE_DESCRIPTOR_MLDB_UPRIGHT',
#  'AKAZE_create',
#  'ALGO_HINT_ACCURATE',
#  'ALGO_HINT_APPROX',
#  'ALGO_HINT_DEFAULT',
#  'AffineFeature',
#  'AffineFeature_create',
#  'AffineTransformer',
#  'AgastFeatureDetector',
#  'AgastFeatureDetector_AGAST_5_8',
#  'AgastFeatureDetector_AGAST_7_12d',
#  'AgastFeatureDetector_AGAST_7_12s',
#  'AgastFeatureDetector_NONMAX_SUPPRESSION',
#  'AgastFeatureDetector_OAST_9_16',
#  'AgastFeatureDetector_THRESHOLD',
#  'AgastFeatureDetector_create',
# ...

# %% [markdown]
# Step-3: Read and show the image
# - in order to show the image it should upload here

# %%
image_cv=cv2.imread('/content/ai +iot.png')
cv2_imshow(image_cv)
# Out:
# <PIL.Image.Image image mode=RGB size=741x650>

# %% [markdown]
# **Convert into gray scale**
#
# cv2.imread ==== read the image
#
# cv2_imshow ==== showing the image
#
# cv2.cvColor

# %%
image_cv.shape
# Out:
# (650, 741, 3)

# %%
gray_image=cv2.cvtColor(image_cv,cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=741x650>

# %%
from google.colab.patches import cv2_imshow
hsv_image=cv2.cvtColor(image_cv,cv2.COLOR_BGR2HSV)
cv2_imshow(hsv_image)
# Out:
# <PIL.Image.Image image mode=RGB size=741x650>

# %%
from google.colab.patches import cv2_imshow
rgb_image=cv2.cvtColor(image_cv,cv2.COLOR_BGR2GRAY)
cv2_imshow(rgb_image)
# Out:
# <PIL.Image.Image image mode=L size=741x650>

# %% [markdown]
# - image # BGR
# - gray_image # black and white
# - rgb_image # rgb
# - hsv_image #hsv

# %%
from google.colab.patches import cv2_imshow
resized_image=cv2.resize(image_cv,(700,500))
cv2_imshow(resized_image)
# Out:
# <PIL.Image.Image image mode=RGB size=700x500>

# %% [markdown]
# ##Cropping

# %% [markdown]
# - cropping means i m selecting part of the image
# - image means pixel number
# - select any number nd check which part is extracting
# - height and width height ranges 0 to 767
# - width ranges 0 to 1366
# - height:[50:200] width[50:200]

# %%
cropped=image_cv[50:200,50:200]
cv2_imshow(cropped)
# Out:
# <PIL.Image.Image image mode=RGB size=150x150>

# %%
flip_image=cv2.flip(image_cv,0)
cv2_imshow(flip_image)
# Out:
# <PIL.Image.Image image mode=RGB size=741x650>

# %%
flip_image=cv2.flip(image_cv,1)
cv2_imshow(flip_image)
# Out:
# <PIL.Image.Image image mode=RGB size=741x650>

# %%
flip_image=cv2.flip(image_cv,-1)
cv2_imshow(flip_image)
# Out:
# <PIL.Image.Image image mode=RGB size=741x650>
