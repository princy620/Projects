# %% [markdown]
# <a href="https://colab.research.google.com/github/princy620/Projects/blob/main/Open_CV_for_Gen_AI_session1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Install the packages

# %%
# !pip install opencv-python

# %% [markdown]
# ## import the packages

# %%
import cv2
from google.colab.patches import cv2_imshow

# %% [markdown]
# ## load the image or read the image

# %%
image_cv=cv2.imread('/content/ai +iot.png')
cv2_imshow(image_cv)
# Out:
# <PIL.Image.Image image mode=RGB size=741x650>

# %%
image_cv.shape
# image is a kind of a matrix
# rows = 650
# columns = 1366
# 3 indicates RGB channel means
# Out:
# (650, 741, 3)

# %%
image_cv
# [61,29,0]  = 61+29+0=== dark blue color
# generally we will talk interms of RGB
# cv consider image in BGR
# 61 === blue color intensity level
# 29 === green color intensity level
# 0 === red color intensity level

# 3 types of R G B
# 0 means low intensity level
# 255 means high intensity(0 to 255)
# Out:
# array([[[61, 29,  0],
#         [54, 23,  1],
#         [49, 19,  0],
#         ...,
#         [48, 21,  0],
#         [48, 21,  1],
#         [48, 20,  1]],
#
#        [[39, 18,  2],
#         [39, 18,  0],
#         [39, 18,  1],
#         ...,
#         [48, 21,  0],
#         [49, 22,  1],
#         [47, 20,  0]],
#
#        [[37, 15,  0],
#         [39, 16,  2],
#         [39, 16,  1],
#         ...,
#         [48, 20,  0],
#         [48, 21,  0],
#         [49, 22,  2]],
#
#        ...,
#
#        [[37, 16,  2],
#         [37, 16,  1],
#         [37, 16,  2],
#         ...,
#         [46, 15,  0],
#         [46, 16,  2],
#         [46, 15,  0]],
#
#        [[37, 16,  2],
#         [37, 16,  0],
#         [37, 16,  0],
#         ...,
#         [46, 16,  1],
#         [45, 15,  0],
#         [47, 16,  2]],
#
#        [[37, 15,  0],
#         [37, 16,  2],
#         [37, 16,  0],
#         ...,
#         [46, 16,  1],
#         [46, 16,  1],
#         [46, 16,  2]]], dtype=uint8)

# %%
cv2.split(image_cv) #1.blue2.green3.red
# Out:
# (array([[61, 54, 49, ..., 48, 48, 48],
#         [39, 39, 39, ..., 48, 49, 47],
#         [37, 39, 39, ..., 48, 48, 49],
#         ...,
#         [37, 37, 37, ..., 46, 46, 46],
#         [37, 37, 37, ..., 46, 45, 47],
#         [37, 37, 37, ..., 46, 46, 46]], dtype=uint8),
#  array([[29, 23, 19, ..., 21, 21, 20],
#         [18, 18, 18, ..., 21, 22, 20],
#         [15, 16, 16, ..., 20, 21, 22],
#         ...,
#         [16, 16, 16, ..., 15, 16, 15],
#         [16, 16, 16, ..., 16, 15, 16],
#         [15, 16, 16, ..., 16, 16, 16]], dtype=uint8),
#  array([[0, 1, 0, ..., 0, 1, 1],
#         [2, 0, 1, ..., 0, 1, 0],
#         [0, 2, 1, ..., 0, 0, 2],
#         ...,
#         [2, 1, 2, ..., 0, 2, 0],
#         [2, 0, 0, ..., 1, 0, 2],
#         [0, 2, 0, ..., 1, 1, 2]], dtype=uint8))

# %%
b,g,r=cv2.split(image_cv)

# %%
b
# Out:
# array([[61, 54, 49, ..., 48, 48, 48],
#        [39, 39, 39, ..., 48, 49, 47],
#        [37, 39, 39, ..., 48, 48, 49],
#        ...,
#        [37, 37, 37, ..., 46, 46, 46],
#        [37, 37, 37, ..., 46, 45, 47],
#        [37, 37, 37, ..., 46, 46, 46]], dtype=uint8)

# %%
g
# Out:
# array([[29, 23, 19, ..., 21, 21, 20],
#        [18, 18, 18, ..., 21, 22, 20],
#        [15, 16, 16, ..., 20, 21, 22],
#        ...,
#        [16, 16, 16, ..., 15, 16, 15],
#        [16, 16, 16, ..., 16, 15, 16],
#        [15, 16, 16, ..., 16, 16, 16]], dtype=uint8)

# %%
r
# Out:
# array([[0, 1, 0, ..., 0, 1, 1],
#        [2, 0, 1, ..., 0, 1, 0],
#        [0, 2, 1, ..., 0, 0, 2],
#        ...,
#        [2, 1, 2, ..., 0, 2, 0],
#        [2, 0, 0, ..., 1, 0, 2],
#        [0, 2, 0, ..., 1, 1, 2]], dtype=uint8)

# %%
cv2_imshow(r)
# Out:
# <PIL.Image.Image image mode=L size=741x650>

# %%
import matplotlib.pyplot as plt
plt.imshow(r,cmap='Reds')

# %%
plt.imshow(g,cmap='Greens')

# %%
plt.imshow(b,cmap='Blues')
